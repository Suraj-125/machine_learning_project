# %% [markdown]
# <h1 style = "background-color : black; color : #fff; padding: 10px 5px">Predicting the Salary</h1>

# %%
# Importing the libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
# %matplotlib inline

# %%
# Reading the csv file

df = pd.read_csv("canada_per_capita_income.csv")
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
# Visualizing the salary on y axis and year on x- axis

plt.title("Canada Salary Prediction")
plt.xlabel("Year")
plt.ylabel("Per Capita Income (US$)")
plt.scatter(df["year"], df["per capita income (US$)"], marker = "+", color = "purple")
plt.show()

# %%
# Fitting the model
reg = linear_model.LinearRegression()
reg.fit(df[["year"]], df["per capita income (US$)"])
# Out:
# LinearRegression()

# %%
# Predicting the salary
reg.predict([[2012]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([34660.97349264])

# %%
# Calculating the coefficient
reg.coef_
# Out:
# array([828.46507522])

# %%
# Calculating the intercept
reg.intercept_
# Out:
# -1632210.7578554575

# %%
# Ploting the predicted salary using matplotlib.
plt.title("Canada Salary Prediction")
plt.xlabel("Year")
plt.ylabel("Salary")
plt.scatter(df["year"], df["per capita income (US$)"], marker = "+", color = "red")
plt.plot(df.year, reg.predict(df[["year"]]), color = "purple")
plt.show()

# %%
# Predicting salary by the help of year
reg.predict([[9059]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[5872854.35858708]])
